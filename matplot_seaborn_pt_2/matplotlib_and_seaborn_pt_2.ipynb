# %% [markdown]
# # Scatterplots and Correlation

# %% [markdown]
# Quantitative vs Quantitative Bivariate Plotting

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline

# %%
fuel_econ = pd.read_csv('data/fuel_econ.csv')
print(fuel_econ.shape)
fuel_econ.head(6)
# Out:
# (3929, 20)
#       id        make           model  year           VClass  \
# 0  32204      Nissan            GT-R  2013  Subcompact Cars
# 1  32205  Volkswagen              CC  2013     Compact Cars
# 2  32206  Volkswagen              CC  2013     Compact Cars
# 3  32207  Volkswagen      CC 4motion  2013     Compact Cars
# 4  32208   Chevrolet  Malibu eAssist  2013     Midsize Cars
# 5  32209       Lexus          GS 350  2013     Midsize Cars
#
#                drive              trans          fuelType  cylinders  displ  \
# 0    All-Wheel Drive    Automatic (AM6)  Premium Gasoline          6    3.8
# 1  Front-Wheel Drive  Automatic (AM-S6)  Premium Gasoline          4    2.0
# 2  Front-Wheel Drive     Automatic (S6)  Premium Gasoline          6    3.6
# 3    All-Wheel Drive     Automatic (S6)  Premium Gasoline          6    3.6
# 4  Front-Wheel Drive     Automatic (S6)  Regular Gasoline          4    2.4
# ...

# %%
plt.scatter(data=fuel_econ, x='displ', y='comb')
plt.xlabel('Displacement (1)')
plt.ylabel('Combined Fuel Eff. (mpg)')
# Out:
# Text(0, 0.5, 'Combined Fuel Eff. (mpg)')

# %%
sb.regplot(data=fuel_econ, x='displ', y='comb', fit_reg=False)
plt.xlabel('Displacement (1)')
plt.ylabel('Combined Fuel Eff. (mpg)')
# Out:
# Text(0, 0.5, 'Combined Fuel Eff. (mpg)')

# %% [markdown]
# # Overplotting, Transparency, Jitter

# %% [markdown]
# Overplotting - Where a plot is created with too many overlapping points
# - Can be fixed with sampling, transparency, and jitter
#
# Random sampling makes less points appear, but still gives an idea for gen distribution due to random selection
# Transparency makes the darker spots == more point density
#
# If your data is _discrete_ you will want to add jitter
# - This adds a small amount of random noise to the position of each point so multi points w/ same values are shown very close together

# %%
sb.regplot(data=fuel_econ, x ='year', y='comb', fit_reg=False)

# %%
sb.regplot(data=fuel_econ, x ='year', y='comb', fit_reg=False, x_jitter = 0.3)

# %%
sb.regplot(
    data=fuel_econ,
    x ='year',
    y='comb',
    fit_reg=False,
    x_jitter = 0.3,
    scatter_kws = {'alpha': 1/5}
    );

# %%
sb.regplot(
    data=fuel_econ,
    x ='year',
    y='comb',
    fit_reg=False,
    x_jitter = 0.3,
    scatter_kws = {'alpha': 1/20}
    );

# %% [markdown]
# # Heat Maps

# %% [markdown]
# Heat map divides field into grid of cells.  Each cell is given a color based on count of data points in it
#
# - Good for 2 discrete variables
# - Good alt to transparency for large amount of data
#
# _Bin size is important!_

# %%
plt.hist2d(data=fuel_econ, x='displ', y='comb');
plt.colorbar()
plt.xlabel('Displacement (1)')
plt.ylabel('Combined Fuel Eff (mpg)')
# Out:
# Text(0, 0.5, 'Combined Fuel Eff (mpg)')

# %%
plt.hist2d(data=fuel_econ, x='displ', y='comb', cmin=0.5);
plt.colorbar()
plt.xlabel('Displacement (1)')
plt.ylabel('Combined Fuel Eff (mpg)')
# Out:
# Text(0, 0.5, 'Combined Fuel Eff (mpg)')

# %%
plt.hist2d(data=fuel_econ, x='displ', y='comb', cmin=0.5, cmap='viridis_r');
plt.colorbar()
plt.xlabel('Displacement (1)')
plt.ylabel('Combined Fuel Eff (mpg)')
# Out:
# Text(0, 0.5, 'Combined Fuel Eff (mpg)')

# %%
fuel_econ[['displ', 'comb']].describe()
# Out:
#              displ         comb
# count  3929.000000  3929.000000
# mean      2.950573    24.791339
# std       1.305901     6.003246
# min       0.600000    12.821700
# 25%       2.000000    20.658100
# 50%       2.500000    24.000000
# 75%       3.600000    28.227100
# max       7.000000    57.782400

# %%
bins_x = np.arange(0.6, 7+0.3, 0.3)
bins_y = np.arange(12, 58+3, 3)

plt.hist2d(data=fuel_econ, x='displ', y='comb', cmin=0.5, cmap='viridis_r',
          bins=[bins_x,bins_y]);
plt.colorbar()
plt.xlabel('Displacement (1)')
plt.ylabel('Combined Fuel Eff (mpg)')
# Out:
# Text(0, 0.5, 'Combined Fuel Eff (mpg)')

# %% [markdown]
# # Scatterplot Practice

# %%
# prerequisite package imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline

from solutions_biv import scatterplot_solution_1, scatterplot_solution_2

# %% [markdown]
# In this workspace, you'll make use of this data set describing various car attributes, such as fuel efficiency. The cars in this dataset represent about 3900 sedans tested by the EPA from 2013 to 2018. This dataset is a trimmed-down version of the data found [here](https://catalog.data.gov/dataset/fuel-economy-data).

# %%
fuel_econ = pd.read_csv('./data/fuel_econ.csv')
fuel_econ.head()
# Out:
#       id        make           model  year           VClass  \
# 0  32204      Nissan            GT-R  2013  Subcompact Cars
# 1  32205  Volkswagen              CC  2013     Compact Cars
# 2  32206  Volkswagen              CC  2013     Compact Cars
# 3  32207  Volkswagen      CC 4motion  2013     Compact Cars
# 4  32208   Chevrolet  Malibu eAssist  2013     Midsize Cars
#
#                drive              trans          fuelType  cylinders  displ  \
# 0    All-Wheel Drive    Automatic (AM6)  Premium Gasoline          6    3.8
# 1  Front-Wheel Drive  Automatic (AM-S6)  Premium Gasoline          4    2.0
# 2  Front-Wheel Drive     Automatic (S6)  Premium Gasoline          6    3.6
# 3    All-Wheel Drive     Automatic (S6)  Premium Gasoline          6    3.6
# 4  Front-Wheel Drive     Automatic (S6)  Regular Gasoline          4    2.4
#
#    pv2  pv4     city    UCity  highway  UHighway     comb  co2  feScore  \
# ...

# %% [markdown]
# **Task 1**: Let's look at the relationship between fuel mileage ratings for city vs. highway driving, as stored in the 'city' and 'highway' variables (in miles per gallon, or mpg). Use a _scatter plot_ to depict the data. What is the general relationship between these variables? Are there any points that appear unusual against these trends?

# %%
sb.regplot(data=fuel_econ,
          x='city',
          y='highway',
          scatter_kws = {'alpha': 1/10}
          )
plt.xlabel('City Fuel Eff (mpg)')
plt.ylabel('Highway Fuel Eff (mpg)');

# %%
# run this cell to check your work against ours
scatterplot_solution_1()
# Out:
# Most of the data falls in a large blob between 10 and 30 mpg city and 20 to 40 mpg highway. Some transparency is added via 'alpha' to show the concentration of data. Interestingly, for most cars highway mileage is clearly higher than city mileage, but for those cars with city mileage above about 30 mpg, the distinction is less pronounced. In fact, most cars above 45 mpg city have better city mileage than highway mileage, contrary to the main trend. It might be good to call out this trend by adding a diagonal line to the figure using the `plot` function. (See the solution file for that code!)

# %% [markdown]
# **Task 2**: Let's look at the relationship between two other numeric variables. How does the engine size relate to a car's CO2 footprint? The 'displ' variable has the former (in liters), while the 'co2' variable has the latter (in grams per mile). Use a heat map to depict the data. How strong is this trend?

# %%
fuel_econ[['displ', 'co2']].describe()
# Out:
#              displ          co2
# count  3929.000000  3929.000000
# mean      2.950573   376.564266
# std       1.305901    92.338892
# min       0.600000    29.000000
# 25%       2.000000   315.000000
# 50%       2.500000   369.000000
# 75%       3.600000   429.000000
# max       7.000000   692.000000

# %%
bins_x = np.arange(0.6, 7+0.5, 0.5)
bins_y = np.arange(29, 692+65, 65)

plt.hist2d(data=fuel_econ,
          x='displ',
          y='co2',
          cmin=0.5,
          cmap='viridis_r',
          bins=[bins_x, bins_y]
          )
plt.colorbar()
plt.xlabel('Displacement (Liters)')
plt.ylabel('CO2');

# %%
# run this cell to check your work against ours
scatterplot_solution_2()
# Out:
# In the heat map, I've set up a color map that goes from light to dark, and made it so that any cells without count don't get colored in. The visualization shows that most cars fall in a line where larger engine sizes correlate with higher emissions. The trend is somewhat broken by those cars with the lowest emissions, which still have engine sizes shared by most cars (between 1 and 3 liters).

# %% [markdown]
# # Violin Plots

# %% [markdown]
# Good plot choice for examining a quantitative vs qualitative variable
#
# Where it is wider, there are more points

# %%
sedan_classes = ['Minicompact Cars', 'Subcompact Cars', 'Compact Cars',
                'Midsize Cars', 'Large Cars']
vclasses = pd.api.types.CategoricalDtype(ordered=True, categories=sedan_classes)
fuel_econ['VClass'] = fuel_econ['VClass'].astype(vclasses);

# %%
sb.violinplot(data=fuel_econ, x='VClass', y='comb');

# %%
base_color = sb.color_palette()[0]
sb.violinplot(data=fuel_econ, x='VClass', y='comb',
             color = base_color);

# %%
base_color = sb.color_palette()[0]
sb.violinplot(data=fuel_econ, x='VClass', y='comb',
             color = base_color)
plt.xticks(rotation=15);

# %%
base_color = sb.color_palette()[0]
sb.violinplot(data=fuel_econ, x='VClass', y='comb',
             color = base_color, inner=None)
plt.xticks(rotation=15);

# %% [markdown]
# # Box Plots

# %% [markdown]
# Also good for quantitative vs qualitative inquiries
#
# By default, sb.violinplot includes a box plot inside of the violin plot (remove it with _inner=None_ parameter)
#
# They look like a box with whiskers.
#
# - The upper whisker is Q4 (the line at the end is the _max value_, excluding outliers)
# - The upper portion of the box is Q3
# - The line in the box is the _median_ (Q2)
# - The lower portion of the box is Q1
# - The lower whisker is Q0 (the line at the end is the _min value_, excluding outliers)
#
# ##### If there are outliers beyond 1.5\*IQR they are represented as dots beyond the whiskers
# _IQR = Q3 - Q1_

# %%
base_color = sb.color_palette()[0]
sb.boxplot(data=fuel_econ, x='VClass', y='comb',
             color = base_color)
plt.xticks(rotation=15);

# %% [markdown]
# You can also get a violin plot with a box plot inside by not including the _inner_ parameter

# %%
base_color = sb.color_palette()[0]
sb.violinplot(data=fuel_econ, x='VClass', y='comb',
             color = base_color)
plt.xticks(rotation=15);

# %% [markdown]
# Or, you can get a violinplot with just the quartile lines using _inner=quartile_

# %%
base_color = sb.color_palette()[0]
sb.violinplot(data=fuel_econ, x='VClass', y='comb',
             color = base_color, inner='quartile')
plt.xticks(rotation=15);

# %% [markdown]
# # Violin and Box Plot Practice

# %%
# prerequisite package imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline

from solutions_biv import violinbox_solution_1

# %% [markdown]
# We'll continue to make use of the fuel economy dataset in this workspace.

# %%
fuel_econ = pd.read_csv('./data/fuel_econ.csv')
fuel_econ.head()
# Out:
#       id        make           model  year           VClass  \
# 0  32204      Nissan            GT-R  2013  Subcompact Cars
# 1  32205  Volkswagen              CC  2013     Compact Cars
# 2  32206  Volkswagen              CC  2013     Compact Cars
# 3  32207  Volkswagen      CC 4motion  2013     Compact Cars
# 4  32208   Chevrolet  Malibu eAssist  2013     Midsize Cars
#
#                drive              trans          fuelType  cylinders  displ  \
# 0    All-Wheel Drive    Automatic (AM6)  Premium Gasoline          6    3.8
# 1  Front-Wheel Drive  Automatic (AM-S6)  Premium Gasoline          4    2.0
# 2  Front-Wheel Drive     Automatic (S6)  Premium Gasoline          6    3.6
# 3    All-Wheel Drive     Automatic (S6)  Premium Gasoline          6    3.6
# 4  Front-Wheel Drive     Automatic (S6)  Regular Gasoline          4    2.4
#
#    pv2  pv4     city    UCity  highway  UHighway     comb  co2  feScore  \
# ...

# %% [markdown]
# **Task**: What is the relationship between the size of a car and the size of its engine? The cars in this dataset are categorized into one of five different vehicle classes based on size. Starting from the smallest, they are: {Minicompact Cars, Subcompact Cars, Compact Cars, Midsize Cars, and Large Cars}. The vehicle classes can be found in the 'VClass' variable, while the engine sizes are in the 'displ' column (in liters). **Hint**: Make sure that the order of vehicle classes makes sense in your plot!

# %%
sedan_classes = ['Minicompact Cars', 'Subcompact Cars', 'Compact Cars', 'Midsize Cars', 'Large Cars']
v_classes = pd.api.types.CategoricalDtype(ordered = True, categories = sedan_classes)
fuel_econ['VClass'] = fuel_econ['VClass'].astype(v_classes)

# %%
base_color = sb.color_palette()[0]
sb.violinplot(data = fuel_econ,
             x = 'VClass',
             y = 'displ',
             inner = 'quartile',
             color = base_color
             )
plt.xticks(rotation = 15)
plt.xlabel('Sedan Class')
plt.ylabel('Displ (liters)');

# %%
# run this cell to check your work against ours
violinbox_solution_1()
# Out:
# I used a violin plot to depict the data in this case; you might have chosen a box plot instead. One of the interesting things about the relationship between variables is that it isn't consistent. Compact cars tend to have smaller engine sizes than the minicompact and subcompact cars, even though those two vehicle sizes are smaller. The box plot would make it easier to see that the median displacement for the two smallest vehicle classes is greater than the third quartile of the compact car class.

# %% [markdown]
# # Clustered Bar Charts

# %% [markdown]
# Used for qualitative vs quantitative comparison

# %%
fuel_econ['trans_type'] = fuel_econ['trans'].apply(lambda x: x.split()[0])

# %%
ct_counts = fuel_econ.groupby(['VClass', 'trans_type']).size()
ct_counts = ct_counts.reset_index(name = 'count')
ct_counts = ct_counts.pivot(index = 'VClass', columns = 'trans_type', values = 'count')

# %%
sb.heatmap(ct_counts);

# %%
sb.countplot(data = fuel_econ, x = 'VClass')
plt.xticks(rotation = 15);

# %%
sb.countplot(data = fuel_econ, x = 'VClass', hue='trans_type')
plt.xticks(rotation = 15)
plt.xlabel('Vehicle Class')
plt.ylabel('Number of Cars')
# Out:
# Text(0, 0.5, 'Number of Cars')

# %% [markdown]
# # Categorical Plot Practice

# %%
# prerequisite package imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline

from solutions_biv import categorical_solution_1

# %% [markdown]
# We'll continue to make use of the fuel economy dataset in this workspace.

# %%
fuel_econ = pd.read_csv('./data/fuel_econ.csv')
fuel_econ.head()
# Out:
#       id        make           model  year           VClass  \
# 0  32204      Nissan            GT-R  2013  Subcompact Cars
# 1  32205  Volkswagen              CC  2013     Compact Cars
# 2  32206  Volkswagen              CC  2013     Compact Cars
# 3  32207  Volkswagen      CC 4motion  2013     Compact Cars
# 4  32208   Chevrolet  Malibu eAssist  2013     Midsize Cars
#
#                drive              trans          fuelType  cylinders  displ  \
# 0    All-Wheel Drive    Automatic (AM6)  Premium Gasoline          6    3.8
# 1  Front-Wheel Drive  Automatic (AM-S6)  Premium Gasoline          4    2.0
# 2  Front-Wheel Drive     Automatic (S6)  Premium Gasoline          6    3.6
# 3    All-Wheel Drive     Automatic (S6)  Premium Gasoline          6    3.6
# 4  Front-Wheel Drive     Automatic (S6)  Regular Gasoline          4    2.4
#
#    pv2  pv4     city    UCity  highway  UHighway     comb  co2  feScore  \
# ...

# %% [markdown]
# **Task**: Use a plot to explore whether or not there differences in recommended fuel type depending on the vehicle class. **Note**: The dataset as provided does not retain any of the sorting of the 'VClass' variable, so you will also need to copy over any code you used previously to sort the category levels.

# %%
fuel_econ['fuelType'] = fuel_econ['fuelType'].apply(lambda x: x.split()[0])

# %%
ft_counts = fuel_econ.groupby(['VClass', 'fuelType']).size()
ft_counts = ft_counts.reset_index(name = 'count')
ft_counts = ft_counts.pivot(index = 'VClass', columns = 'fuelType', values = 'count')

# %%
sb.countplot(data = fuel_econ, x = 'VClass', hue='fuelType')
plt.legend(loc='upper right')
plt.xticks(rotation = 15)
plt.xlabel('Vehicle Class')
plt.ylabel('Num Vehicles');

# %% [markdown]
# # Faceting
